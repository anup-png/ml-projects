# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/asus/Downloads/BostonHousing.csv")

# %%
df.head(
)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print(df['chas'].value_counts())
print(df['rad'].value_counts())
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64
# rad
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: count, dtype: int64

# %%
df.isnull().any()
# Out:
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm          True
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# b          False
# lstat      False
# medv       False
# dtype: bool

# %%
df['rm'].fillna(df['rm'].mean(),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15312\1852253395.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rm'].fillna(df['rm'].mean(),inplace=True)

# %%
df.isnull().any()
# Out:
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm         False
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# b          False
# lstat      False
# medv       False
# dtype: bool

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219261  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.310847 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.392052  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091434  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302051  0.731470
# rm      -0.219261  0.310847 -0.392052  0.091434 -0.302051  1.000000 -0.239632
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.239632  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.202268 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210353  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292178  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356065  0.261515
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,Y_train,X_test,Y_test = train_test_split(df.drop(['chas','rad','medv'],axis=1),df['medv'],test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train,Y_train,X_test,Y_test = train_test_split(df.drop('chas','rad','medv'),df['medv'],test_size=0.2,random_state=42)
#
# TypeError: DataFrame.drop() takes from 1 to 2 positional arguments but 4 were given
